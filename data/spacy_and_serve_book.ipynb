# %%
import spacy
import re
from collections import Counter

# %%
FNAME = '../data/a_portrait_new.txt'
input_file = open(FNAME, encoding='utf8').readlines()

# we replace all the unwanted symbols (@, #, $) and clean the text
pat = r'[^a-zA-z0-9.,!?/:;\"\'\s]' 
modded = [re.sub(pat, '', x.strip()) for x in input_file]
modded = [x for x in modded if x != '']
joined_sentences = ' '.join(modded)

# load the cleaned sentences in spacy
nlp = spacy.load("en_core_web_sm")
start_data = nlp(joined_sentences)

# %%
# individual sentences in which we find a given NE record
# sents = [ent.sent for ent in start_data.ents if ent.text == 'Dante']
# print(len(sents))

mentions_sents = dict()

# all entities, counted and all of the sentences in which they were mentioned
# create the initial data schema for the entities of type PERSON
# that we will at some point persist in a database 
visited = []
for ent in start_data.ents:
    if ent.label_ == 'PERSON':
        sent_string = str(ent.sent)
        if ent.text not in visited:
            visited.append(ent.text)
            mentions_sents[ent.text] = {
                'count': 1,
                'sent': {sent_string: {'additional': [], 'times': sent_string.count(ent.text)}}
            }
        else:
            mentions_sents[ent.text]['count'] = mentions_sents[ent.text]['count'] + 1
            mentions_sents[ent.text]['sent'][sent_string] = {'additional': [], 'times': sent_string.count(ent.text)}

# %%
# Create a set of all the entities for the lookup below
all_ner = set([ent.text for ent in start_data.ents if ent.label_ == 'PERSON'])

# %%
# This is making me a little bit sick (tripple nested loops)
# maybe implement it with generators to be faster or at least to look better
for ner, elements in mentions_sents.items():
    for k, v in elements.get('sent').items():
        for name in all_ner:
            if name != ner and name in k:
                # if we want to add the count as well
                mentions_sents[ner]['sent'][k]['additional'].append(name)

# %%
# we create a counter object to use the most_common method to get the entity with highest count
items = [x.text for x in start_data.ents if x.label_ == 'PERSON']
cter = Counter(items)

# %%
min_val = 1
max_val = cter.most_common(1)[0][1]

# this function accepts the passed count value and determines the rank of the entity
# based on a simple 33/33/33
def calc_rank(count):
    percentage = ((count - min_val) * 100) / (max_val - min_val)

    if percentage <= 33:
        return 3
    elif percentage > 33 and percentage <= 66:
        return 2
    else:
        return 1

# %%
# iterate through the entities, set their rank
def set_rank(mentions_sents):
    for entity, vals in mentions_sents.items():
        mentions_sents[entity]['rank'] = calc_rank(vals['count'])

# %%
set_rank(mentions_sents)

# %%
# represent the entities from the data
for entity in mentions_sents:
    print(f"Name: {entity} --> Count: {mentions_sents[entity]['count']} --> Rank: {mentions_sents[entity]['rank']}")
# Out:
# Name: James Joyce Chapter --> Count: 1 --> Rank: 3
# Name: Betty Byrne --> Count: 1 --> Rank: 3
# Name: Tralala --> Count: 3 --> Rank: 3
# Name: Uncle Charles --> Count: 10 --> Rank: 3
# Name: Dante --> Count: 47 --> Rank: 1
# Name: Charles --> Count: 20 --> Rank: 2
# Name: Michael Davitt --> Count: 2 --> Rank: 3
# Name: Eileen --> Count: 6 --> Rank: 3
# Name: Apologize --> Count: 3 --> Rank: 3
# Name: Rody Kickham --> Count: 4 --> Rank: 3
# Name: Nasty Roche --> Count: 9 --> Rank: 3
# Name: Stephen Dedalus --> Count: 5 --> Rank: 3
# Name: Jack Lawtons --> Count: 1 --> Rank: 3
# Name: Hamilton Rowan --> Count: 2 --> Rank: 3
# Name: Wolsey --> Count: 2 --> Rank: 3
# Name: Arnall --> Count: 22 --> Rank: 2
# Name: Simon Moonan --> Count: 9 --> Rank: 3
# Name: Arnalls --> Count: 3 --> Rank: 3
# Name: Jack Lawton --> Count: 6 --> Rank: 3
# Name: Jimmy Magee --> Count: 2 --> Rank: 3
# Name: Tullabeg --> Count: 1 --> Rank: 3
# Name: Wells --> Count: 8 --> Rank: 3
# Name: Casey --> Count: 35 --> Rank: 1
# Name: Ill --> Count: 17 --> Rank: 2
# Name: Canker --> Count: 1 --> Rank: 3
# Name: Leicester Abbey --> Count: 1 --> Rank: 3
# Name: Michael --> Count: 18 --> Rank: 2
# Name: Little --> Count: 1 --> Rank: 3
# Name: Brigid --> Count: 1 --> Rank: 3
# Name: Farewell --> Count: 1 --> Rank: 3
# Name: Athy --> Count: 13 --> Rank: 3
# Name: Dedalus --> Count: 10 --> Rank: 3
# Name: Nasty Roches --> Count: 1 --> Rank: 3
# Name: Queen Victoria --> Count: 1 --> Rank: 3
# Name: Mrs Riordan --> Count: 7 --> Rank: 3
# Name: Christopher --> Count: 1 --> Rank: 3
# Name: Christy --> Count: 1 --> Rank: 3
# Name: jack --> Count: 1 --> Rank: 3
# Name: Mrs Dedalus --> Count: 15 --> Rank: 3
# Name: John --> Count: 5 --> Rank: 3
# Name: Ally Daly --> Count: 1 --> Rank: 3
# Name: Simon --> Count: 5 --> Rank: 3
# Name: Mary --> Count: 1 --> Rank: 3
# Name: Stephens --> Count: 48 --> Rank: 1
# Name: Billy --> Count: 1 --> Rank: 3
# Name: Armagh --> Count: 1 --> Rank: 3
# Name: Dante hotlythe language --> Count: 1 --> Rank: 3
# Name: Tullamore --> Count: 1 --> Rank: 3
# Name: MARY AND JOSEPH! --> Count: 1 --> Rank: 3
# Name: Kitty OShea --> Count: 1 --> Rank: 3
# Name: Sergeant ONeill --> Count: 1 --> Rank: 3
# Name: Godforsaken --> Count: 2 --> Rank: 3
# Name: Bishop Lanigan --> Count: 1 --> Rank: 3
# Name: Cecil Thunder --> Count: 7 --> Rank: 3
# Name: Kickhams --> Count: 1 --> Rank: 3
# Name: Barrett --> Count: 1 --> Rank: 3
# Name: Corrigan --> Count: 4 --> Rank: 3
# Name: Gleeson --> Count: 1 --> Rank: 3
# Name: Lady Boyle --> Count: 1 --> Rank: 3
# Name: Flemings --> Count: 2 --> Rank: 3
# Name: Kneel --> Count: 3 --> Rank: 3
# Name: Paddy Barrett --> Count: 1 --> Rank: 3
# Name: Tom Furlongs --> Count: 1 --> Rank: 3
# Name: Richmal Magnalls Questions --> Count: 1 --> Rank: 3
# Name: Peter Parleys --> Count: 1 --> Rank: 3
# Name: Peter Parley --> Count: 2 --> Rank: 3
# Name: Ignatius Loyola --> Count: 1 --> Rank: 3
# Name: Francis Xavier --> Count: 8 --> Rank: 3
# Name: Lorenzo Ricci --> Count: 1 --> Rank: 3
# Name: Stanislaus Kostka --> Count: 1 --> Rank: 3
# Name: Aloysius Gonzago --> Count: 1 --> Rank: 3
# Name: Blessed John Berchmans --> Count: 1 --> Rank: 3
# Name: Peter Kenny --> Count: 1 --> Rank: 3
# Name: Dolan --> Count: 6 --> Rank: 3
# Name: Baldyhead Dolan --> Count: 1 --> Rank: 3
# Name: Bartons --> Count: 1 --> Rank: 3
# Name: Mike Flynn --> Count: 5 --> Rank: 3
# Name: Dundrum --> Count: 1 --> Rank: 3
# Name: Munster --> Count: 1 --> Rank: 3
# Name: Aubrey Mills --> Count: 1 --> Rank: 3
# Name: Aubrey --> Count: 3 --> Rank: 3
# Name: Dublin --> Count: 1 --> Rank: 3
# Name: Josephine --> Count: 3 --> Rank: 3
# Name: Ellen --> Count: 1 --> Rank: 3
# Name: Roderick Kickham --> Count: 1 --> Rank: 3
# Name: John Lawton --> Count: 1 --> Rank: 3
# Name: Anthony MacSwiney --> Count: 1 --> Rank: 3
# Name: L. D. S. --> Count: 1 --> Rank: 3
# Name: Micky Mud --> Count: 1 --> Rank: 3
# Name: Maurice --> Count: 4 --> Rank: 3
# Name: Annoyed --> Count: 1 --> Rank: 3
# Name: The Blessed Sacrament --> Count: 1 --> Rank: 3
# Name: Mrs Tallon --> Count: 1 --> Rank: 3
# Name: Bertie Tallon --> Count: 1 --> Rank: 3
# Name: Wallis --> Count: 5 --> Rank: 3
# Name: Vincent Heron --> Count: 2 --> Rank: 3
# Name: Jove --> Count: 1 --> Rank: 3
# Name: Marryat --> Count: 1 --> Rank: 3
# Name: Newman --> Count: 3 --> Rank: 3
# Name: Cardinal Newman --> Count: 2 --> Rank: 3
# Name: Tennyson --> Count: 3 --> Rank: 3
# Name: Tyson --> Count: 1 --> Rank: 3
# Name: Alec Kafoozelum --> Count: 1 --> Rank: 3
# Name: Byron --> Count: 2 --> Rank: 3
# Name: Afraid --> Count: 1 --> Rank: 3
# Name: Doyle --> Count: 3 --> Rank: 3
# Name: Mick Lacy --> Count: 2 --> Rank: 3
# Name: Harry Peard --> Count: 1 --> Rank: 3
# Name: Bob Dyas --> Count: 1 --> Rank: 3
# Name: Maurice Moriarty --> Count: 1 --> Rank: 3
# Name: Tom OGrady --> Count: 1 --> Rank: 3
# Name: Joey Corbet --> Count: 1 --> Rank: 3
# Name: Johnny Keevers --> Count: 1 --> Rank: 3
# Name: Simon Dedalus --> Count: 1 --> Rank: 3
# Name: Dedaluss --> Count: 1 --> Rank: 3
# Name: Lee --> Count: 1 --> Rank: 3
# Name: Johnny Cashman --> Count: 2 --> Rank: 3
# Name: John Stephen Dedalus --> Count: 1 --> Rank: 3
# Name: Johnny --> Count: 2 --> Rank: 3
# Name: Tim --> Count: 1 --> Rank: 3
# Name: Tom --> Count: 1 --> Rank: 3
# Name: Henry Grattan --> Count: 1 --> Rank: 3
# Name: Charles Kendal Bushe --> Count: 1 --> Rank: 3
# Name: Willie --> Count: 1 --> Rank: 3
# Name: Bertie --> Count: 1 --> Rank: 3
# Name: Shelleys --> Count: 2 --> Rank: 3
# Name: SICUT CINNAMOMUM ET --> Count: 1 --> Rank: 3
# Name: James --> Count: 1 --> Rank: 3
# Name: Francis --> Count: 1 --> Rank: 3
# Name: EARTHLY BEAUTY --> Count: 2 --> Rank: 3
# Name: DANGEROUS --> Count: 2 --> Rank: 3
# Name: Lucifer --> Count: 3 --> Rank: 3
# Name: God Himself --> Count: 2 --> Rank: 3
# Name: Merciful Redeemer --> Count: 1 --> Rank: 3
# Name: Saint Catherine --> Count: 1 --> Rank: 3
# Name: Saint Thomas --> Count: 1 --> Rank: 3
# Name: POENA DAMNI --> Count: 1 --> Rank: 3
# Name: Augustine --> Count: 1 --> Rank: 3
# Name: Him --> Count: 1 --> Rank: 3
# Name: Saviour --> Count: 1 --> Rank: 3
# Name: Frowsy --> Count: 1 --> Rank: 3
# Name: Longer --> Count: 2 --> Rank: 3
# Name: Divine Perfections --> Count: 1 --> Rank: 3
# Name: Meek --> Count: 1 --> Rank: 3
# Name: the Blessed Sacrament --> Count: 1 --> Rank: 3
# Name: Alphonsus Liguori --> Count: 1 --> Rank: 3
# Name: Thomas --> Count: 2 --> Rank: 3
# Name: Louis Veuillot --> Count: 1 --> Rank: 3
# Name: Foxy Campbell --> Count: 1 --> Rank: 3
# Name: Sour --> Count: 1 --> Rank: 3
# Name: Becauseboro --> Count: 1 --> Rank: 3
# Name: Clontarf Chapel --> Count: 1 --> Rank: 3
# Name: Clontail Chapel --> Count: 1 --> Rank: 3
# Name: Dan Crosby --> Count: 1 --> Rank: 3
# Name: Hickey --> Count: 1 --> Rank: 3
# Name: Quaid --> Count: 1 --> Rank: 3
# Name: Keogh --> Count: 1 --> Rank: 3
# Name: Dwyer --> Count: 1 --> Rank: 3
# Name: Stephaneforos --> Count: 4 --> Rank: 3
# Name: Towser --> Count: 1 --> Rank: 3
# Name: Shuley --> Count: 1 --> Rank: 3
# Name: Connolly --> Count: 1 --> Rank: 3
# Name: Cripes --> Count: 1 --> Rank: 3
# Name: Daly --> Count: 1 --> Rank: 3
# Name: Gerhart Hauptmann --> Count: 1 --> Rank: 3
# Name: Guido Cavalcanti --> Count: 1 --> Rank: 3
# Name: Ibsen --> Count: 1 --> Rank: 3
# Name: Liffey --> Count: 1 --> Rank: 3
# Name: Ben Jonson --> Count: 2 --> Rank: 3
# Name: Aristotle --> Count: 2 --> Rank: 3
# Name: IVORY --> Count: 1 --> Rank: 3
# Name: John Duncan --> Count: 1 --> Rank: 3
# Name: William Malcolm Inverarity --> Count: 1 --> Rank: 3
# Name: Davin --> Count: 19 --> Rank: 2
# Name: Michael Cusack --> Count: 1 --> Rank: 3
# Name: Mat Davin --> Count: 1 --> Rank: 3
# Name: Stevie --> Count: 5 --> Rank: 3
# Name: Fonsy Davin --> Count: 1 --> Rank: 3
# Name: Crokes --> Count: 1 --> Rank: 3
# Name: Ballyhoura --> Count: 1 --> Rank: 3
# Name: Wolfe Tone --> Count: 1 --> Rank: 3
# Name: Stephens Green --> Count: 1 --> Rank: 3
# Name: Buck Egan --> Count: 1 --> Rank: 3
# Name: Buck Whaleys --> Count: 1 --> Rank: 3
# Name: Lordin --> Count: 1 --> Rank: 3
# Name: VISA PLACENT --> Count: 2 --> Rank: 3
# Name: Peter Byrne --> Count: 1 --> Rank: 3
# Name: Moynihan --> Count: 11 --> Rank: 3
# Name: W. S. Gilbert --> Count: 1 --> Rank: 3
# Name: F. W. Martino --> Count: 1 --> Rank: 3
# Name: QUOD --> Count: 1 --> Rank: 3
# Name: Cranlys --> Count: 11 --> Rank: 3
# Name: QUIA FACIES VOSTRA MONSTRAT UT --> Count: 1 --> Rank: 3
# Name: HUMORE ESTIS --> Count: 1 --> Rank: 3
# Name: Elizabethan English --> Count: 1 --> Rank: 3
# Name: Marx --> Count: 1 --> Rank: 3
# Name: Collins --> Count: 1 --> Rank: 3
# Name: John Anthony Collins --> Count: 2 --> Rank: 3
# Name: John Anthonys --> Count: 1 --> Rank: 3
# Name: Lottie Collins --> Count: 1 --> Rank: 3
# Name: Fianna --> Count: 1 --> Rank: 3
# Name: Moran --> Count: 2 --> Rank: 3
# Name: Lynch --> Count: 5 --> Rank: 3
# Name: Goggins --> Count: 5 --> Rank: 3
# Name: ARREST --> Count: 1 --> Rank: 3
# Name: Rhythm --> Count: 1 --> Rank: 3
# Name: Plato --> Count: 1 --> Rank: 3
# Name: Patrick Duns --> Count: 1 --> Rank: 3
# Name: Maundy --> Count: 1 --> Rank: 3
# Name: Donovan --> Count: 6 --> Rank: 3
# Name: INTEGRITAS --> Count: 1 --> Rank: 3
# Name: Shelley --> Count: 1 --> Rank: 3
# Name: Luigi Galvani --> Count: 1 --> Rank: 3
# Name: COMIC --> Count: 1 --> Rank: 3
# Name: THAT IMAGE --> Count: 1 --> Rank: 3
# Name: Moycullen --> Count: 1 --> Rank: 3
# Name: Rise --> Count: 2 --> Rank: 3
# Name: Cornelius Agrippa --> Count: 1 --> Rank: 3
# Name: Thoth --> Count: 1 --> Rank: 3
# Name: Oona --> Count: 1 --> Rank: 3
# Name: Dixon --> Count: 22 --> Rank: 2
# Name: Walter Scott --> Count: 2 --> Rank: 3
# Name: Scott --> Count: 1 --> Rank: 3
# Name: Davins --> Count: 1 --> Rank: 3
# Name: Forster --> Count: 1 --> Rank: 3
# Name: Francis Forster --> Count: 1 --> Rank: 3
# Name: Clanbrassil --> Count: 1 --> Rank: 3
# Name: Baldwin --> Count: 1 --> Rank: 3
# Name: Vaguely --> Count: 1 --> Rank: 3
# Name: Glynn --> Count: 7 --> Rank: 3
# Name: Saint Augustine --> Count: 1 --> Rank: 3
# Name: Roman --> Count: 1 --> Rank: 3
# Name: Depart --> Count: 1 --> Rank: 3
# Name: Aloysius Gonzaga --> Count: 1 --> Rank: 3
# Name: Suarez --> Count: 1 --> Rank: 3
# Name: Rosie OGrady --> Count: 2 --> Rank: 3
# Name: Rosie first --> Count: 1 --> Rank: 3
# Name: Juan Mariana de Talavera --> Count: 1 --> Rank: 3
# Name: Hence Cranlys --> Count: 1 --> Rank: 3
# Name: Elizabeth --> Count: 1 --> Rank: 3
# Name: Item --> Count: 1 --> Rank: 3
# Name: Began --> Count: 2 --> Rank: 3
# Name: Bruno --> Count: 1 --> Rank: 3
# Name: William Bond --> Count: 1 --> Rank: 3
# Name: William --> Count: 1 --> Rank: 3
# Name: William Ewart Gladstone --> Count: 1 --> Rank: 3
# Name: Orchestra --> Count: 1 --> Rank: 3
# Name: Mooney --> Count: 1 --> Rank: 3
# Name: OBriens --> Count: 1 --> Rank: 3
# Name: Met Davin --> Count: 1 --> Rank: 3
# Name: Tara --> Count: 1 --> Rank: 3
# Name: VIA Holyhead --> Count: 1 --> Rank: 3
# Name: Michael Robartes --> Count: 1 --> Rank: 3
# Name: John Alphonsus Mulrennan --> Count: 1 --> Rank: 3
# Name: Dante Alighieri --> Count: 1 --> Rank: 3
